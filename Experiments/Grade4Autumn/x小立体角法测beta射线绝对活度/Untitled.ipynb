# %%
# -*- coding: utf-8 -*-
from physicsexp.mainfunc import *
from physicsexp.gendocx import *

# %%
weight = np.array([0, 2, 4, 6, 8, 10]) * 2.869 + 2.5 + 7.70
count = np.array([6930, 6375, 5919, 5643, 5405, 5104]) - 10

# %%
simple_linear_plot(weight, np.log(count), title='对数计数与吸收介质厚度图', ylab='计数', xlab='厚度mg/cm2')
# Out:
# (-0.010335215444457218, 8.928747266930078)

# %%
np.exp(8.92875)
# Out:
# 7545.827194622647
