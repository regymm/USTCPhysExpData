# %%
# -*- coding: utf-8 -*-
from physicsexp.mainfunc import *
from physicsexp.gendocx import *

# %%
energy_pos = np.array([406.47, 353.33, 471.98, 568.17, 438.85].sort())
Ka = np.array([7.477, 6.403, 8.638, 10.549, 8.047].sort())

# %%
s, i = simple_linear_plot(energy_pos, Ka, xlab='道址', ylab='频率K', title='峰位道址与K关系', save='1.png')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-9e991662c86a> in <module>
# ----> 1 s, i = simple_linear_plot(energy_pos, Ka, xlab='道址', ylab='频率K', title='峰位道址与K关系', save='1.png')
#
# /usr/local/lib/python3.7/site-packages/physicsexp/mainfunc.py in simple_linear_plot(x, y, xlab, ylab, dot, dotlab, linelab, title, save, show, issetrange, islegend)
#     268 def simple_linear_plot(x, y, xlab='x', ylab='y',
#     269         dot='o', dotlab='原始数据', linelab='拟合直线', title='title', save=0, show=1, issetrange=0, islegend=1):
# --> 270     result = linear_regression(x, y, simple=0)
#     271     if issetrange:
#     272         setrange(x, y, xy=0b11)
#
# /usr/local/lib/python3.7/site-packages/physicsexp/mainfunc.py in linear_regression(x, y, quiet, simple)
#      32 # 线性回归，最小二乘法
#      33 def linear_regression(x, y, quiet=1, simple=1):
# ---> 34     slope, intercept, r_value, p_value, std_err = stats.linregress(x, y)
#      35     r_squared = r_value ** 2
#      36     s_slope = slope * math.sqrt((r_value ** -2 - 1) / (len(x) - 2))
#
# /usr/local/lib/python3.7/site-packages/scipy/stats/_stats_mstats_common.py in linregress(x, y)
#     109         raise ValueError("Inputs must not be empty.")
#     110
# --> 111     n = len(x)
#     112     xmean = np.mean(x, None)
#     113     ymean = np.mean(y, None)
#
# TypeError: len() of unsized object

# %%
# X sample
print(356.13 * s + i)
# 1 nickle coin
print(357.46 * s + i) # similar to Fe? Don't know. Said to be Steel + Nickle
# Out:
# 6.4661400986245
# 6.4916378359248315

# %%
# Al thickness: 1.77 um

# %%
# Cu
time = np.array([71, 82, 97, 127, 116, 143, 173])
area = np.array([22402, 21510, 20778, 22367, 17503, 17702, 17941])

# %%
s, i =simple_linear_plot(np.array([x for x in range(7)]), np.log(area / time), xlab='铝片数', ylab='X射线强度（对数）', title='Cu吸收曲线', save='2.png')

# %%
print(-s) # unit: um^-1
# Out:
# 0.18536975481164758

# %%
# Zn
time = np.array([66, 77, 87, 94, 108, 125, 160])
area = np.array([24988, 24789, 24375, 22469, 22560, 22600, 24585])

# %%
s, i =simple_linear_plot(np.array([x for x in range(7)]), np.log(area / time), xlab='铝片数', ylab='X射线强度（对数）', title='Zn吸收曲线', save='3.png')

# %%
print(-s) # unit: um^-1
# Out:
# 0.1483162277058294

# %%
gendocx('gen.docx', '1.png', '2.png', '3.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-24-dce0d1d8e5d3> in <module>
# ----> 1 gendocx('gen.docx', '1.png', '2.png', '3.png')
#
# /usr/local/lib/python3.7/site-packages/physicsexp/gendocx.py in gendocx(name, title, *elem)
#      16         i = str(i)
#      17         if i[-4:] in imglist:
# ---> 18             docu.add_picture(i, width=Inches(5.))
#      19         else:
#      20             docu.add_paragraph(i)
#
# /usr/local/lib/python3.7/site-packages/docx/document.py in add_picture(self, image_path_or_stream, width, height)
#      70         """
#      71         run = self.add_paragraph().add_run()
# ---> 72         return run.add_picture(image_path_or_stream, width, height)
#      73
#      74     def add_section(self, start_type=WD_SECTION.NEW_PAGE):
#
# /usr/local/lib/python3.7/site-packages/docx/text/run.py in add_picture(self, image_path_or_stream, width, height)
#      60         value is specified, as is often the case.
#      61         """
# ---> 62         inline = self.part.new_pic_inline(image_path_or_stream, width, height)
#      63         self._r.add_drawing(inline)
#      64         return InlineShape(inline)
#
# /usr/local/lib/python3.7/site-packages/docx/parts/story.py in new_pic_inline(self, image_descriptor, width, height)
#      54         based on the values of *width* and *height*.
#      55         """
# ---> 56         rId, image = self.get_or_add_image(image_descriptor)
#      57         cx, cy = image.scaled_dimensions(width, height)
#      58         shape_id, filename = self.next_id, image.filename
#
# /usr/local/lib/python3.7/site-packages/docx/parts/story.py in get_or_add_image(self, image_descriptor)
#      27         such as dimensions and image type.
#      28         """
# ---> 29         image_part = self._package.get_or_add_image_part(image_descriptor)
#      30         rId = self.relate_to(image_part, RT.IMAGE)
#      31         return rId, image_part.image
#
# /usr/local/lib/python3.7/site-packages/docx/package.py in get_or_add_image_part(self, image_descriptor)
#      29         collection.
#      30         """
# ---> 31         return self.image_parts.get_or_add_image_part(image_descriptor)
#      32
#      33     @lazyproperty
#
# /usr/local/lib/python3.7/site-packages/docx/package.py in get_or_add_image_part(self, image_descriptor)
#      72         collection.
#      73         """
# ---> 74         image = Image.from_file(image_descriptor)
#      75         matching_image_part = self._get_by_sha1(image.sha1)
#      76         if matching_image_part is not None:
#
# /usr/local/lib/python3.7/site-packages/docx/image/image.py in from_file(cls, image_descriptor)
#      44         if is_string(image_descriptor):
#      45             path = image_descriptor
# ---> 46             with open(path, 'rb') as f:
#      47                 blob = f.read()
#      48                 stream = BytesIO(blob)
#
# FileNotFoundError: [Errno 2] No such file or directory: '3.png'
