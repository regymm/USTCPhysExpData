# %%
# -*- coding: utf-8 -*-
from physicsexp.mainfunc import *
from physicsexp.gendocx import *

# %%
# voltage for 2.5MPa, 2.0MPa, 1.5MPa, 1.0MPa
volt = np.array([0, 7.5, 15, 22.5, 30, 37.5, 45, 52.5, 60, 75, 90, 105, 120, 135, 150, 165, 180, 195, 210, 225, 240, 255, 270, 285, 300, 315, 330, 345])
# count
count1 = [
    np.array([218, 837, 1131, 1287, 1335, 1355, 1361, 1361, 1375, 1378, 1382, 1377, 1383, 1387, 1383, 1382, 1385, 1386, 1386, 1386, 1389, 1389, 1387, 1388, 1387, 1387, 1387, 1383]),
    np.array([227, 825, 1040, 1100, 1112, 1124, 1118, 1119, 1115, 1119, 1118, 1117, 1116, 1116, 1116, 1113, 1110, 1111, 1107, 1108, 1109, 1108, 1111, 1113, 1111, 1108, math.nan, math.nan]), 
    np.array([232, 704, 851 , 873 , 877 , 875 , 874 , 875 , 874 , 879 , 878 , 881 , 879 , 882 , 882 , 880 , 881 , 881 , 880 , 880 , 881 , 882 , 884 , 881 , 883 , 882 , 882 , 882 ]),
    np.array([226, 577, 605 , 604 , 604 , 604 , 606 , 607 , 608 , 609 , 609 , 608 , 611 , 608 , 610 , 609 , 610 , 610 , 609 , 607 , 609 , 609 , 610 , 610 , 609 , 610 , 612 , 609 ])
]

# %%
simple_plot(volt, count1[-1], show=0, lab='气压1.0MPa', dot='x')
simple_plot(volt, count1[-2], show=0, lab='气压1.5MPa', dot='o')
simple_plot(volt, count1[-3], show=0, lab='气压2.0MPa', dot='.')
simple_plot(volt, count1[-4], show=1, lab='气压2.5MPa', dot='*', xlab='高压（V）', ylab='计数（平均电离电流）', title='饱和曲线', save='1.png')
plt.show()

# %%
count2 = [
    np.array([ 34, 460, 719, 851, 975,1017,1057,1092,1111,1151,1170,1189,1201,1208,1214,1221,1226,1228,1238,1238,1242,1246,1248,1252,1254,1255,1259,1257]),
    np.array([ 78, 425, 602, 705, 779, 822, 853, 874, 892, 917, 929, 942, 948, 953, 958, 962, 967, 970, 976, 973, 980, 981, 984, 984, 986, 987, 987, 992]),
    np.array([  0, 384, 460, 539, 604, 633, 646, 660, 673, 679, 692, 700, 707, 707, 713, 715, 716, 720, 722, 723, 727, 727, 729, 729, 731, 731, math.nan, math.nan]),
    np.array([  0, 268, 391, 446, 477, 502, 513, 522, 527, 545, 546, 552, 555, 556, 559, 562, 563, 565, 565, 569, 571, 570, 573, 572, 573, 574, math.nan, math.nan])
]

# %%
simple_plot(volt, count2[-1], show=0, lab='3片金属片阻挡', dot='x')
simple_plot(volt, count2[-2], show=0, lab='2片金属片阻挡', dot='o')
simple_plot(volt, count2[-3], show=0, lab='1片金属片阻挡', dot='.')
simple_plot(volt, count2[-4], show=1, lab='无金属片阻挡', dot='*', xlab='高压（V）', ylab='计数（平均电离电流）', title='线形范围曲线', save='2.png')
plt.show()

# %%
pos = [i for i in range(36)]
count = [[511, 508], [601, 602], [774, 776], [808, 809], [811, 812], [808, 808], [816, 819], 
                 827, 830, 830, 830, 830, 832, 828, 828, 836, 829, 831, 832, 834, 833, 831, 829, 831, 830, 826, 
                 [827, 828], [821, 822], [822, 820], [818, 820], [813, 814], [812, 812], [807, 805], [798, 801], [779, 780], [754, 753]]

# %%
count3 = [(i[0] + i[1])/2 if type(i) is list else i for i in count]

# %%
simple_plot(pos, count3, xlab='位置', ylab='计数', title='轴向均匀性曲线', save='3.png')

# %%
gendocx('gen.docx', '1.png', '2.png', '3.png')
